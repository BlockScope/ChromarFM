-- %%
:load AnalysisEvents.hs
import Data.Colour
import Data.Colour.Names
import AnalysisEvents
import qualified Data.Map as M
import Types
import GHC.Exts
-- Out:
-- AnalysisEvents.hs: openFile: does not exist (No such file or directory)

-- %%
livesLL <- fmap getLfDistr (readEvents "../out/lifeExpsVal/outEventsH_d0.0_r0.598.txt")
livesHH <- fmap getLfDistr (readEvents "../out/lifeExpsVal/outEventsH_d2.5_r0.737.txt")

-- %%
let lensLL = map (/24) (getLens livesLL)
    lensHH = map (/24) (getLens livesHH)

-- %%
plotHistsGridR 1 [mkHist' [blue, red] "days" "lengths" [lensLL, lensHH]]

-- %%
let vegLL = map (/24) (vegSLen livesLL)
    reprLL = map (/24) (reprSLen livesLL)
    dormLL = map (/24) (dormSLen livesLL)
    
let vegHH = map (/24) (vegSLen livesHH)
    reprHH = map (/24) (reprSLen livesHH)
    dormHH = map (/24) (dormSLen livesHH)    
    
plotHistsGridR 3 [mkHist' [blue,red] "days" "veg len" [vegLL, vegHH], 
 mkHist' [blue,red] "days" "repr len" [reprLL, reprHH],
 mkHist' [blue,red] "days" "dorm len" [dormLL, dormHH]]

-- %% [markdown]
-- ![alt](scratch/lengthsvalh.png "")

-- %%
let germTLL = map (germT .> getDayYear) livesLL
    flowerTLL = map (flowerT .> getDayYear) livesLL
    ssetTLL = map (ssetT .> getDayYear) livesLL
    
let germTHH = map (germT .> getDayYear) livesHH
    flowerTHH = map (flowerT .> getDayYear) livesHH
    ssetTHH = map (ssetT .> getDayYear) livesHH
    
plotHistsGrid "scratch/timingsvalh.png" 3 [mkHist' [blue, red] "day of year" "germ time" [germTLL, germTHH],
 mkHist' [blue, red] "day of year" "flower time" [flowerTLL, flowerTHH],
 mkHist' [blue, red] "day of year" "sset time" [ssetTLL, ssetTHH]]

-- %% [markdown]
-- ![alt](scratch/timingsvalh.png "")

-- %% [markdown]
-- Seems to be a similar story with hourly data.

-- %% [markdown]
-- ### Lifecycles LL

-- %%
let (lsl1, lsl2) = sortLFs (100*24) (360*24) livesLL

-- %%
let lensl1 = map (/24) (getLens lsl1)
    lensl2 = map (/24) (getLens lsl2)

-- %%
plotHistsGridR 1 [mkHist' [blue, red] "days" "lens LL 1" [lensl1, lensl2]]

-- %%
let germl1 = map (germT .> getDayYear) lsl1
    germl2 = map (germT .> getDayYear) lsl2
    
let vegl1 = map (/24) (vegSLen lsl1)
    vegl2 = map (/24) (vegSLen lsl2)

-- %%
plotHistsGridR 1  [mkHist' [blue, red] "days" "veg len -LL" [vegl1, vegl2]]

-- %%
length lsl1
length lsl2
-- Out:
-- 204
-- 865

-- %%
plotHistsGridR 1  [mkHist' [blue, red] "day of year" "germ time -LL" [germl1, germl2]]

-- %%
median germl1
median vegl1
-- Out:
-- 197.0
-- 21.207766788761848

-- %%
median germl2
median vegl2
-- Out:
-- 271.0
-- 83.74892493854593

-- %%
(fromIntegral (length lsl1) * 0.015) + (fromIntegral (length lsl2) *2)
-- Out:
-- 1733.06

-- %% [markdown]
-- ### Lifecycles HH

-- %%
let (lsh1, lsh2) = sortLFs (400*24) (700*24) livesHH

-- %%
length lsh1
length lsh2
-- Out:
-- 392
-- 235

-- %%
let lensh1 = map (/24) (getLens lsh1)
    lensh2 = map (/24) (getLens lsh2)

-- %%
plotHistsGridR 1 [mkHist' [blue, red] "days" "lens HH 1" [lensh1, lensh2]]

-- %%
let germh1 = map (germT .> getDayYear) lsh1
    germh2 = map (germT .> getDayYear) lsh2
    
let vegh1 = map (/24) (vegSLen lsh1)
    vegh2 = map (/24) (vegSLen lsh2)

-- %%
plotHistsGridR 1  [mkHist' [blue, red] "day of year" "germ time -HH" [germh1, germh2]]

-- %%
plotHistsGridR 1  [mkHist' [blue, red] "day of year" "veg len -HH" [vegh1, vegh2]]

-- %%
median germh1
median vegh1
-- Out:
-- 282.0
-- 112.83447629451985

-- %%
median germh2
median vegh2
-- Out:
-- 268.0
-- 108.90228673249658

-- %%
length lsh1
length lsh2
-- Out:
-- 392
-- 235

-- %%
idlivesLL <- fmap groupById (readEvents "../out/lifeExpsVal/outEventsH_d0.0_r0.598.txt")
idlivesHH <- fmap groupById (readEvents "../out/lifeExpsVal/outEventsH_d2.5_r0.737.txt")

-- %%
let biomass1 = 10
let biomass2 = 10

-- %%
(fromIntegral (length lsh1) * biomass1) + (fromIntegral (length lsh2) * biomass2)
-- Out:
-- 6270
